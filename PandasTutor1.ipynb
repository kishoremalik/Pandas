# %% [markdown]
# ## Pandas ETL operation
# -  create Data
# -  Get Data
# -  Data access through iloc and loc

# %%
from pandas import DataFrame, read_csv

# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number

# Enable inline plotting
# %matplotlib inline

# %%
# version check
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 3.6.5 |Anaconda, Inc.| (default, Mar 29 2018, 13:32:41) [MSC v.1900 64 bit (AMD64)]
# Pandas version 0.23.0
# Matplotlib version 2.2.2

# %% [markdown]
# ## Create Data

# %%
# The inital set of baby names and birth rates
names = ['Bob','Jessica','Mary','John','Mel']
births = [968, 155, 77, 578, 973]
# The inital set of baby names and birth rates
BabyDataSet = list(zip(names,births))
BabyDataSet
# Out:
# [('Bob', 968), ('Jessica', 155), ('Mary', 77), ('John', 578), ('Mel', 973)]

# %%
df = pd.DataFrame(data = BabyDataSet, columns=['Names', 'Births'])
df
# Out:
#      Names  Births
# 0      Bob     968
# 1  Jessica     155
# 2     Mary      77
# 3     John     578
# 4      Mel     973

# %%
# store the data in csv files
df.to_csv('D:/rough/births1880.csv',index=False,header=False)

# %% [markdown]
# # Get Data

# %%
#read csv files
Location = r'D:/rough/diabetes.csv'

df = pd.read_table(Location,sep=',')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
# reading text data
location1='D:/rough/audiology.txt'

data = pd.read_table(location1, header=None)
data
# Out:
#                                                      0
# 0    [p1,cochlear_unknown,[boneAbnormal,air(mild),a...
# 1    [p2,cochlear_unknown,[boneAbnormal,air(moderat...
# 2    [p3,mixed_cochlear_age_fixation,[age_gt_60,air...
# 3    [p4,mixed_cochlear_age_otitis_media,[age_gt_60...
# 4    [p5,cochlear_age,[age_gt_60,boneAbnormal,air(m...
# 5    [p6,cochlear_age,[age_gt_60,boneAbnormal,air(m...
# 6    [p7,cochlear_unknown,[boneAbnormal,air(mild),a...
# 7    [p8,cochlear_unknown,[boneAbnormal,air(mild),a...
# 8    [p9,cochlear_unknown,[boneAbnormal,air(severe)...
# 9    [p10,cochlear_age,[age_gt_60,boneAbnormal,air(...
# 10   [p11,cochlear_age,[age_gt_60,boneAbnormal,air(...
# 11   [p12,cochlear_age,[age_gt_60,boneAbnormal,air(...
# 12   [p13,cochlear_unknown,[boneAbnormal,air(severe...
# 13   [p14,normal_ear,[air(normal),ar_c(elevated),ar...
# 14   [p15,cochlear_age,[age_gt_60,boneAbnormal,air(...
# 15   [p16,cochlear_age,[age_gt_60,boneAbnormal,air(...
# ...

# %% [markdown]
# ## accessing column and rows

# %%
# using iloc
print(df.columns)
df.iloc[0:4,0:2]
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')
#    Pregnancies  Glucose
# 0            6      148
# 1            1       85
# 2            8      183
# 3            1       89

# %%
# using loc
df.loc[0:5,['Glucose','Pregnancies','Outcome']]
# Out:
#    Glucose  Pregnancies  Outcome
# 0      148            6        1
# 1       85            1        0
# 2      183            8        1
# 3       89            1        0
# 4      137            0        1
# 5      116            5        0

# %%
df[['Glucose','Pregnancies','Outcome']]
# Out:
#      Glucose  Pregnancies  Outcome
# 0        148            6        1
# 1         85            1        0
# 2        183            8        1
# 3         89            1        0
# 4        137            0        1
# 5        116            5        0
# 6         78            3        1
# 7        115           10        0
# 8        197            2        1
# 9        125            8        1
# 10       110            4        0
# 11       168           10        1
# 12       139           10        0
# 13       189            1        1
# 14       166            5        1
# 15       100            7        1
# 16       118            0        1
# 17       107            7        1
# 18       103            1        0
# 19       115            1        1
# 20       126            3        0
# 21        99            8        0
# 22       196            7        1
# 23       119            9        1
# 24       143           11        1
# 25       125           10        1
# ...

# %%
# selecting 5 rows for a column

df['Glucose'][:5]
# Out:
# 0    148
# 1     85
# 2    183
# 3     89
# 4    137
# Name: Glucose, dtype: int64
